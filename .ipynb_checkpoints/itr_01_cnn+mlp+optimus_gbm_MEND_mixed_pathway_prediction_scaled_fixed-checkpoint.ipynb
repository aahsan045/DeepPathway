# %%
# !pip install scanpy
# !pip3 install opencv-python
# !pip install harmonypy

# %%
import torch
import torch.nn.functional as F
from tqdm import tqdm
import matplotlib.pyplot as plt
import scanpy as sc
import timm
import os
import json
import numpy as np
import pandas as pd
import cv2
from sklearn.decomposition import TruncatedSVD
# from scipy.sparse import csr_matrix
import torchvision.transforms.functional as TF
import random
import openslide
from PIL import Image
from tqdm import tqdm
import scipy.io as sio
from torch import nn
# from utils import AvgMeter
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import scanpy as sc
import argparse
import scipy as si
from sklearn.model_selection import train_test_split
from spatialdata import read_zarr

from __future__ import annotations

# Clear logger to use tiatoolbox.logger
import logging

if logging.getLogger().hasHandlers():
    logging.getLogger().handlers.clear()

from pathlib import Path

import matplotlib as mpl
import requests
import skimage.color

from tiatoolbox import data, logger
from tiatoolbox.tools import stainnorm
from tiatoolbox.wsicore import wsireader
import matplotlib.pyplot as plt
# Out:
# /home/e90244aa/anaconda3/envs/bleep_env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /home/e90244aa/anaconda3/envs/bleep_env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /home/e90244aa/anaconda3/envs/bleep_env/lib/python3.10/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# |2025-10-29|10:47:30.875| [WARNING] It looks like you are using Pixman version 0.38 (via conda). This version is known to cause issues with OpenSlide. Please consider upgrading to Pixman version 0.39 or later. You may be able do this with the command: conda install -c conda-forge pixman">=0.39"

# %%
seed = 42

# Set seed for Python random module
random.seed(seed)

# Set seed for NumPy
np.random.seed(seed)

# Set seed for PyTorch
torch.manual_seed(seed)

# Set seed for CUDA
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# Ensure deterministic behavior in CUDA operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Set environment variable for Python hash
os.environ['PYTHONHASHSEED'] = str(seed)

# %%
class AvgMeter:
    def __init__(self, name="Metric"):
        self.name = name
        self.reset()

    def reset(self):
        self.avg, self.sum, self.count = [0] * 3

    def update(self, val, count=1):
        self.count += count
        self.sum += val * count
        self.avg = self.sum / self.count

    def __repr__(self):
        text = f"{self.name}: {self.avg:.4f}"
        return text

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group["lr"]

# %%
# all_densenet_models = timm.list_models('*resnet*')
# all_densenet_models

# %%
target_image = data.stain_norm_target()
plt.imshow(target_image)
plt.axis("off")
plt.show()

# %%
method_name_list = ["Reinhard", "Ruifrok", "Macenko", "Vahadane"]
method_name = "Reinhard"
stain_normalizer = stainnorm.get_normalizer(method_name)
stain_normalizer.fit(target_image)

# %%
class ImageEncoder(nn.Module):
    """
    Encode images to a fixed size vector
    """

    def __init__(
        self, model_name="resnet18", pretrained=True, trainable=True
    ):
        super().__init__()

        self.model = timm.create_model(
            model_name, pretrained, num_classes=0, global_pool="avg"
        )
        for p in self.model.parameters():
            p.requires_grad = trainable

    def forward(self, x):
        return self.model(x)
class ProjectionHead(nn.Module):
    def __init__(
        self,
        embedding_dim,
        projection_dim=256,
        dropout=0.35
    ):
        super().__init__()
        self.projection = nn.Linear(embedding_dim, projection_dim)
        self.gelu = nn.GELU()
        self.fc = nn.Linear(projection_dim, projection_dim)
        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(projection_dim)

    def forward(self, x):
        projected = self.projection(x)
        x = self.gelu(projected)
        x = self.dropout(x)
        x = self.fc(x)
        x = self.dropout(x)
        x = x + projected
        x = self.layer_norm(x)
        return x
    
class MLP(nn.Module):
    def __init__(
        self,
        embedding_dim,
        projection_dim=128,
        dropout=0.3
    ):
        super().__init__()
        self.projection = nn.Linear(embedding_dim, projection_dim)
        self.layer_norm1 = nn.LayerNorm(projection_dim)  # LayerNorm for the projection layer
        self.gelu = nn.GELU()  # You can try ReLU or LeakyReLU too
        self.dropout1 = nn.Dropout(0.2)  # Dropout after the projection
        
        self.fc1 = nn.Linear(projection_dim, 128)  # Increased the size
        self.layer_norm2 = nn.LayerNorm(128)  # LayerNorm for the first fully connected layer
        self.dropout2 = nn.Dropout(0.20)  # Dropout after the first FC
        
        self.fc2 = nn.Linear(128, 47) #Additional layer
        self.last_layer = nn.Sigmoid()

    def forward(self, x):
        projected = self.projection(x)
        x = self.layer_norm1(projected)  # LayerNorm after projection
        x = self.gelu(x)
        x = self.dropout1(x)  # Dropout after projection

        x = self.fc1(x)
        x = self.layer_norm2(x)  # LayerNorm after first FC
        x = self.gelu(x)  # Non-linearity after first FC
        x = self.dropout2(x)  # Dropout after first FC
        x = self.fc2(x)
        x = self.last_layer(x)
        return x

# %%
class CLIPModel(nn.Module):
    def __init__(
        self,
        temperature=1.0,
        image_embedding=2048,
        spot_embedding=47,
    ):
        super().__init__()
        self.image_encoder = ImageEncoder()
        self.image_projection = ProjectionHead(embedding_dim=image_embedding) #aka the input dim, 2048 for resnet50
        self.spot_projection = ProjectionHead(embedding_dim=spot_embedding)#224 shared hvgs
        self.temperature = temperature

    def forward(self, batch):
        # Getting Image and spot Features
        image_features = self.image_encoder(batch["image"])
        spot_features = batch["reduced_expression"]
        enc = batch['pos encodings']
        optim_feat = batch['st_feat']
        image_features = torch.cat((image_features,optim_feat),dim=1)
        image_embeddings = self.image_projection(image_features) + enc
        spot_embeddings = self.spot_projection(spot_features) + enc
        # Calculating the Loss
        logits = (spot_embeddings @ image_embeddings.T) / self.temperature
        images_similarity = image_embeddings @ image_embeddings.T
        spots_similarity = spot_embeddings @ spot_embeddings.T
        targets = F.softmax(
            (images_similarity + spots_similarity) / 2 * self.temperature, dim=-1
        )
        spots_loss = cross_entropy(logits, targets, reduction='none')
        images_loss = cross_entropy(logits.T, targets.T, reduction='none')
#         l2_regularization = 0.001 * torch.norm(spot_embeddings, p=2)
        l1_regularization_spots = 0.0001 * torch.norm(spot_embeddings, p=1)
        l1_regularization_image = 0.0001 * torch.norm(image_embeddings, p=1)
#     + 0.0001 * torch.norm(image_embeddings, p=1)
        loss =  ((images_loss + spots_loss) / 2.0 ).mean() + l1_regularization_spots + l1_regularization_image # shape: (batch_size)

        return loss

# %%
class MyModel(nn.Module):
    def __init__(self,device,root_path):
        super().__init__()
        self.device = torch.device(device)
        self.image_model = CLIPModel().to(self.device)
        root_path  = root_path
        checkpoint = torch.load(root_path+"itr_01_Bleep+optimus_prostate_pathways_mixed_patients.pt")
        self.image_model.load_state_dict(checkpoint)
        for param in self.image_model.parameters():
            param.requires_grad = False  # Freezing the model parameters

        # Initialize MLP
        self.img_linear = MLP(embedding_dim=256) # Image embedding dimension
        
    def forward(self, batch):
        images = batch["image"]
        enc= batch['pos encodings']
        true = batch["reduced_expression"]
        optim_feat = batch['st_feat']
        image_features = self.image_model.image_encoder(images) # + enc.float()
        image_features = torch.cat((image_features,optim_feat),dim=1)
        image_features = self.image_model.image_projection(image_features) 
        l1_regularization_image = 0.0001 * torch.norm(image_features, p=1)
        preds = self.img_linear(image_features.float())
        ws = 1 + torch.abs(true - 0.1546) * 5  # Example weighting function
        mae_loss = torch.mean(torch.abs(preds - true))
        # Combine with regularization
        loss = mae_loss + l1_regularization_image
        return loss

# %%
def train_epoch(model, train_loader, optimizer, lr_scheduler=None):
    loss_meter = AvgMeter()
    tqdm_object = tqdm(train_loader, total=len(train_loader))
    for batch in tqdm_object:
        batch = {k: v.cuda(device) for k, v in batch.items() if k == "image" or k == "reduced_expression" or k =='pos encodings' or k =='st_feat'}
        optimizer.zero_grad()
        loss = model(batch)
        loss.backward()
        optimizer.step()
        count = batch["image"].size(0)
        loss_meter.update(loss.item(), count)
        tqdm_object.set_postfix(train_loss=loss_meter.avg, lr=get_lr(optimizer))
    return loss_meter


def test_epoch(model, test_loader):
    loss_meter = AvgMeter()
    tqdm_object = tqdm(test_loader, total=len(test_loader))
    for batch in tqdm_object:
        batch = {k: v.cuda(device) for k, v in batch.items() if k == "image" or k == "reduced_expression" or k =='pos encodings' or k =='st_feat'}
        loss = model(batch)
        count = batch["image"].size(0)
        loss_meter.update(loss.item(), count)
        tqdm_object.set_postfix(valid_loss=loss_meter.avg)
    return loss_meter

# %%
class STDataset(torch.utils.data.Dataset):
    def __init__(self, image_path, spatial_data_path, image_files_path):
        self.whole_image=openslide.OpenSlide(image_path)
        self.level_dims = self.whole_image.level_dimensions[0]
        self.sdata_object = read_zarr(spatial_data_path)
        self.spatial_pos_csv = self.sdata_object['adata_pathways'].obs
        self.spatial_pos_csv = self.spatial_pos_csv.reset_index().rename(columns={'index': 'barcode'})
        self.spatial_pos_csv.columns = range(self.spatial_pos_csv.shape[1])
        self.spatial_pos_csv = self.spatial_pos_csv[self.spatial_pos_csv[1] == 1]
        self.barcode_csv = self.sdata_object['adata_pathways'].obs_names.values
        self.reduced_matrix = np.array(self.sdata_object['adata_pathways'].X)
        self.images_file_path = np.load(image_files_path, allow_pickle=True)
        self.static_features = np.array(self.sdata_object['optim_feat'].X)

        print("Finished loading all files")

    def get_positional_encoding(self, x, y, W, H, d_model=512):
        # Normalize coordinates
        x_norm = x / W
        y_norm = y / H
        # Initialize positional encoding array
        pos_encoding = np.zeros((d_model,))
        # Define frequencies
        freqs = [1 / (10000 ** (2 * i / d_model)) for i in range(d_model // 4)]
        # Apply sine and cosine functions to normalized coordinates
        pos_encoding[0:d_model // 4] = np.sin(x_norm * np.array(freqs))
        pos_encoding[d_model // 4:d_model // 2] = np.cos(x_norm * np.array(freqs))
        pos_encoding[d_model // 2:3 * d_model // 4] = np.sin(y_norm * np.array(freqs))
        pos_encoding[3 * d_model // 4:] = np.cos(y_norm * np.array(freqs))
        return pos_encoding

    def new_transform(self, image):
        transform = transforms.Compose([transforms.ToTensor()])
        return transform(image)

    def __getitem__(self, idx):
        item = {}
        barcode = self.barcode_csv[idx]
        v1 = self.spatial_pos_csv.loc[self.spatial_pos_csv[0] == barcode, 4].values[0] 
        v2 = self.spatial_pos_csv.loc[self.spatial_pos_csv[0] == barcode, 5].values[0]
        pos_encodings = self.get_positional_encoding(v2, v1, self.level_dims[1], self.level_dims[0], 256)
        image = cv2.cvtColor(cv2.imread(self.images_file_path[idx]), cv2.COLOR_BGR2RGB)
        image = self.new_transform(image)
        item['image'] = image
        temp = torch.tensor(self.reduced_matrix[idx, :]).float()
        item['st_feat'] = torch.tensor(self.static_features[idx, :]).float()
        item['reduced_expression'] = temp  # cell x features (3467)
        item['pos encodings'] = pos_encodings
        return item

    def __len__(self):
        return len(self.barcode_csv)

# %%
torch.cuda.device_count()
# Out:
# 2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
root_path  = "/home/e90244aa/Bleep/prostate cancer/"

# %%
def build_loaders(a,root_path="/home/e90244aa/Bleep/prostate cancer/"):
    # One sample will be left out for testing
    print("Building loaders")
    data=[]
    for i in range(0,len(a)):
        d = STDataset(image_path =root_path+"wsis/"+a[i]+".tif",
                      spatial_data_path = root_path+"SpatialData/"+a[i]+"_spatial_data.zarr",
                      image_files_path = root_path+"H&E patches/"+a[i]+"_sample_file_paths.npy"
                      )
        data.append(d)

    dataset = torch.utils.data.ConcatDataset(data)

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size], generator=torch.Generator().manual_seed(seed))
    print(len(train_dataset), len(test_dataset))
    print("train/test split completed")
    train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
    print("Finished building loaders")
    return train_loader, test_loader

# %%
class EarlyStopping:
    def __init__(self, patience=7, delta=0, path='checkpoint.pt', verbose=False):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
            path (str): Path for the checkpoint to be saved.
            verbose (bool): If True, prints a message for each validation loss improvement.
        """
        self.patience = patience
        self.delta = delta
        self.path = path
        self.verbose = verbose
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(model)
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.save_checkpoint(model)
            self.counter = 0

    def save_checkpoint(self, model):
        """Saves model when validation loss decreases."""
        if self.verbose:
            print(f"Validation loss decreased. Saving model to {self.path}" )
        torch.save(model.state_dict(), self.path)

# %%
train_set_a= ['MEND139','MEND140','MEND141','MEND145','MEND148','MEND150','MEND152','MEND153']
train_set_b=["MEND154","MEND157","MEND159","MEND161"]
a=train_set_a+train_set_b
print(a)
# Out:
# ['MEND139', 'MEND140', 'MEND141', 'MEND145', 'MEND148', 'MEND150', 'MEND152', 'MEND153', 'MEND154', 'MEND157', 'MEND159', 'MEND161']

# %%
train_loader,test_loader=build_loaders(a)
# Out:
# Building loaders
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# 20518 5130
# train/test split completed
# Finished building loaders

# %%
device = torch.device("cuda:0")
model = MyModel("cuda:1",root_path).to(device)
print("Image encoder is ResNet18")
# Out:
# |2025-10-29|10:53:40.876| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|10:53:41.006| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Image encoder is ResNet18

# %%
# optimizer = torch.optim.AdamW(model.parameters(), lr=1e-2, weight_decay=1e-2)
tr_loss=[]
tst_loss=[]
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
best_loss = float('inf')
best_epoch = 0
early_stopping = EarlyStopping(patience=3, verbose=True, path=root_path+"itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt")

# args = parser.parse_args()
for epoch in range(15):
    print(f"Epoch: {epoch + 1}")
    model.train()
    train_loss = train_epoch(model, train_loader, optimizer)
    tr_loss.append(train_loss.avg)

    model.eval()
    with torch.no_grad():
        test_loss = test_epoch(model, test_loader)
        lss = test_loss.avg
        tst_loss.append(lss)

    if lss < best_loss:
        best_loss = lss
        best_epoch = epoch
        print(f"Best loss at Epoch: {epoch + 1}")
        torch.save(model.state_dict(), root_path+"itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt")

    # Early Stopping Check
    early_stopping(lss, model)
    if early_stopping.early_stop:
        print("Early stopping")
        break
del train_loader, test_loader, model, optimizer,early_stopping
# Out:
# Epoch: 1
# 100%|████████████████| 81/81 [00:50<00:00,  1.60it/s, lr=0.001, train_loss=3.82]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.34it/s, valid_loss=0.961]
# Best loss at Epoch: 1
# Validation loss decreased. Saving model to /home/e90244aa/Bleep/prostate cancer/itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt
# Epoch: 2
# 100%|████████████████| 81/81 [00:47<00:00,  1.70it/s, lr=0.001, train_loss=3.77]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.65it/s, valid_loss=0.959]
# Best loss at Epoch: 2
# Validation loss decreased. Saving model to /home/e90244aa/Bleep/prostate cancer/itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt
# Epoch: 3
# 100%|████████████████| 81/81 [00:47<00:00,  1.69it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.66it/s, valid_loss=0.952]
# Best loss at Epoch: 3
# Validation loss decreased. Saving model to /home/e90244aa/Bleep/prostate cancer/itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt
# Epoch: 4
# 100%|████████████████| 81/81 [00:47<00:00,  1.69it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.67it/s, valid_loss=0.949]
# Best loss at Epoch: 4
# Validation loss decreased. Saving model to /home/e90244aa/Bleep/prostate cancer/itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt
# Epoch: 5
# 100%|████████████████| 81/81 [00:47<00:00,  1.69it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.71it/s, valid_loss=0.949]
# Best loss at Epoch: 5
# Validation loss decreased. Saving model to /home/e90244aa/Bleep/prostate cancer/itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt
# Epoch: 6
# 100%|████████████████| 81/81 [00:47<00:00,  1.69it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.62it/s, valid_loss=0.949]
# EarlyStopping counter: 1 out of 3
# Epoch: 7
# 100%|████████████████| 81/81 [00:48<00:00,  1.68it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.73it/s, valid_loss=0.949]
# Best loss at Epoch: 7
# Validation loss decreased. Saving model to /home/e90244aa/Bleep/prostate cancer/itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt
# Epoch: 8
# 100%|████████████████| 81/81 [00:48<00:00,  1.67it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.65it/s, valid_loss=0.949]
# EarlyStopping counter: 1 out of 3
# Epoch: 9
# 100%|████████████████| 81/81 [00:48<00:00,  1.68it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.62it/s, valid_loss=0.949]
# Best loss at Epoch: 9
# Validation loss decreased. Saving model to /home/e90244aa/Bleep/prostate cancer/itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt
# Epoch: 10
# 100%|████████████████| 81/81 [00:48<00:00,  1.68it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.71it/s, valid_loss=0.949]
# EarlyStopping counter: 1 out of 3
# Epoch: 11
# 100%|████████████████| 81/81 [00:48<00:00,  1.69it/s, lr=0.001, train_loss=3.76]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.65it/s, valid_loss=0.949]
# EarlyStopping counter: 2 out of 3
# Epoch: 12
# 100%|████████████████| 81/81 [00:48<00:00,  1.69it/s, lr=0.001, train_loss=3.75]
# 100%|█████████████████████████| 81/81 [00:12<00:00,  6.65it/s, valid_loss=0.949]
# EarlyStopping counter: 3 out of 3
# Early stopping

# %%
def build_loaders_inference(id):
    print("Building loaders")
    a=[id]
    data=[]
    for i in range(0,len(a)):
        d = STDataset(image_path =root_path+"wsis/"+a[i]+".tif",
                      spatial_data_path = root_path+"SpatialData/"+a[i]+"_spatial_data.zarr",
                      image_files_path = root_path+"H&E patches/"+a[i]+"_sample_file_paths.npy"
                      )
        data.append(d)

    dataset = torch.utils.data.ConcatDataset(data)
    test_loader = DataLoader(dataset, batch_size=256, shuffle=False, num_workers=0, pin_memory=True, drop_last=False)
    print("Finished building loaders")
    return test_loader

def get_image_embeddings_1(model_path, model,sample_name):
    test_loader = build_loaders_inference(sample_name)
    state_dict = torch.load(model_path)
    model.load_state_dict(state_dict)
    model.eval()
    print("Finished loading model")
    
    test_image_embeddings = []
    with torch.no_grad():
        for batch in tqdm(test_loader):
            images = batch["image"].cuda()
            image_features = model.image_encoder(images)
            optim_feat = batch['st_feat'].cuda()
            image_features = image_features # + batch['pos encodings'].cuda().float()
            image_features = torch.cat((image_features,optim_feat),dim=1)
            preds = model.image_projection(image_features)
            test_image_embeddings.append(preds)
    return torch.cat(test_image_embeddings)

def get_image_embeddings_2(model_path, model,image_embeddings):
    state_dict = torch.load(model_path)
    model.load_state_dict(state_dict)
    model.eval()
    print("Finished loading model")
    
    test_image_embeddings = []
    with torch.no_grad():
        for each in image_embeddings:
            preds = model.img_linear(torch.tensor(each).float().unsqueeze(0).cuda())
            test_image_embeddings.append(preds)
    return torch.cat(test_image_embeddings)

# %%
from scipy import stats
from numpy.linalg import norm
def get_statistics(true,pred):
    corr_cells = np.zeros(pred.shape[0])
    sp_corr_cells = np.zeros(pred.shape[0])
    cosine_cells = np.zeros(pred.shape[0])
    for i in range(pred.shape[0]):
        corr_cells[i] = np.corrcoef(pred[i,:], true[i,:])[0,1]
        sp_corr_cells[i]=stats.spearmanr(pred[i,:], true[i,:])[0]
        cosine_cells[i] = np.dot(pred[i,:], true[i,:])/(norm(pred[i,:])*norm(true[i,:]))

    corr_cells = corr_cells[~np.isnan(corr_cells)]
    sp_corr_cells = sp_corr_cells[~np.isnan(sp_corr_cells)]
    cosine_cells = cosine_cells[~np.isnan(cosine_cells)]


    print("Mean Pearson correlation across All spots (genewise correlation): ", np.mean(corr_cells))
    print("Mean Spearman correlation across spots: ", np.mean(sp_corr_cells))
    print("Mean Cosine Similarity across spots: ", np.mean(cosine_cells))


    corr_pathways = np.zeros(pred.shape[1])
    sp_corr_paths=np.zeros(pred.shape[1])
    cosine_pathways = np.zeros(pred.shape[1])
    for i in range(pred.shape[1]):
        corr_pathways[i] = np.corrcoef(pred[:,i], true[:,i],)[0,1]
        sp_corr_paths[i]=stats.spearmanr(pred[:,i], true[:,i])[0]
        cosine_pathways[i] = np.dot(pred[:,i], true[:,i])/(norm(pred[:,i])*norm(true[:,i]))

    corr_pathways = corr_pathways[~np.isnan(corr_pathways)]
    sp_corr_paths = sp_corr_paths[~np.isnan(sp_corr_paths)]
    cosine_pathways = cosine_pathways[~np.isnan(cosine_pathways)]


    print("Mean Pearson correlation across pathways: ", np.mean(corr_pathways))

    print("Mean Spearman correlation across pathways: ", np.mean(sp_corr_paths))
    print("Mean Cosine Similarity across pathways: ", np.mean(cosine_pathways))
    true_filetered=[]
    for k in range(0,corr_pathways.shape[0]):
        if corr_pathways[k] ==np.nan:
            continue
        else:
            true_filetered.append(true[:, k])
    true_filetered = np.array(true_filetered).T
    print(true_filetered.shape)
    ind = np.argsort(np.sum(true_filetered, axis=0))[-5:]
    # print("highly expressed indices",ind)
    print("mean Pearson correlation highly expressed pathways: ", np.mean(corr_pathways[ind]))
    ind = np.argsort(np.var(true_filetered, axis=0))[-5:]
    print("mean Pearson correlation highly variable pathways: ", np.mean(corr_pathways[ind]))
    return
import math
def contains_nan(sublist):
    return any(isinstance(item, float) and math.isnan(item) for item in sublist)

def get_PCC_dist(true,pred):
    res2=[]
    res3=[]
    for i in range(0,pred.shape[1]):
        x = np.corrcoef(true[:,i], pred[:,i])[0,1]
        res2.append([i,x])
        res3.append(x)
    res3_sorted = np.array(sorted(res3,reverse=True))
    res3_sorted = res3_sorted[~np.isnan(res3_sorted)]
    th=0.10
    print("Mean PCC of pathways having correlation value >="+str(th),np.mean(res3_sorted[res3_sorted>=th]))
    print("Total number of Such Pathways",len(res3_sorted[res3_sorted>=th]))
    cleaned_data = [sublist for sublist in res2 if not contains_nan(sublist)]
    sorted_data = sorted(cleaned_data, key=lambda x: x[1], reverse=True)
    print(sorted_data)
    for each in sorted_data:
        print(each[1])
    return

# %%
a= ["MEND142","MEND143","MEND144","MEND146","MEND147","MEND149","MEND151","MEND156","MEND158","MEND160"]
for sample_name in a:
    print(sample_name)
    model_path_1 = root_path+"itr_01_Bleep+optimus_prostate_pathways_mixed_patients.pt"
    model_path_2 = root_path+"itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt"
    dev_name = "cuda:0"
    device = torch.device(dev_name)
    model1= CLIPModel().to(device)
    model2 = MyModel(dev_name,root_path).to(device)
    img_embeddings_all= get_image_embeddings_1(model_path_1, model1,sample_name)
    pred = get_image_embeddings_2(model_path_2,model2,img_embeddings_all).cpu().numpy()
    sdata = read_zarr(root_path+"SpatialData/"+sample_name+"_spatial_data.zarr")
    true=sdata['adata_pathways'].X
    get_statistics(true,pred)
    get_PCC_dist(true,pred)
# Out:
# MEND142
# |2025-10-29|11:17:24.536| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11
# 0.3248749829263683
# 0.31791463202530007
# 0.3154866210166582
# 0.25890508792081973
# 0.2425296035164734
# 0.23723861897274018
# 0.23123561683609517
# 0.22575465719067447
# 0.2193481511060845
# 0.2058979037613087
# 0.20314749998440298
# 0.19261316731258643
# 0.1897915525208091
# 0.1897101204135366
# 0.18831462947044053
# 0.18657490232638638
# 0.17985761196683642
# 0.17313066448277037
# 0.16614639275371682
# 0.15438262712330966
# 0.1526462396797828
# 0.15147735437824741
# 0.14764951925509195
# 0.14517554270001395
# 0.11969561727606055
# 0.11828538761171242
# 0.1120753274404752
# 0.1118264438960296
# 0.108263780025173
# 0.09076996713086499
# 0.07650740542894303
# 0.07329317091430909
# 0.06808106681735926
# 0.06736763793748575
# 0.018058795347252514
# MEND147
# |2025-10-29|11:18:02.889| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:03.003| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# |2025-10-29|11:18:03.095| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:03.217| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Building loaders
# Finished loading all files
# Finished building loaders
# Finished loading model
# 100%|█████████████████████████████████████████████| 9/9 [00:05<00:00,  1.70it/s]
# |2025-10-29|11:18:08.686| [WARNING] /tmp/ipykernel_620191/3944429404.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds = model.img_linear(torch.tensor(each).float().unsqueeze(0).cuda())
# Finished loading model
# Mean Pearson correlation across All spots (genewise correlation):  0.8546305794578595
# Mean Spearman correlation across spots:  0.8382397659478665
# Mean Cosine Similarity across spots:  0.9735566202362052
# Mean Pearson correlation across pathways:  0.2474170130305022
# Mean Spearman correlation across pathways:  0.2451822156393563
# Mean Cosine Similarity across pathways:  0.9594473204534141
# (2183, 47)
# mean Pearson correlation highly expressed pathways:  0.41477187744989175
# mean Pearson correlation highly variable pathways:  0.41477187744989175
# Mean PCC of pathways having correlation value >=0.1 0.26360056436433593
# Total number of Such Pathways 43
# [[14, 0.5878484163397365], [15, 0.4895949816622442], [25, 0.4868924591747626], [29, 0.483931399140292], [23, 0.4453476949256825], [32, 0.4197834543587954], [2, 0.41525082348364617], [16, 0.41131882558286037], [27, 0.401003144904774], [44, 0.39015666060839527], [33, 0.352498804843364], [12, 0.2995192752066872], [13, 0.29925499235642933], [18, 0.2747789398838175], [19, 0.27460679419906614], [31, 0.2699755481814913], [41, 0.26043760326685167], [36, 0.2586531940188091], [35, 0.24857762202129258], [17, 0.2484369558608834], [7, 0.24002247841538102], [0, 0.2399207469763924], [38, 0.22389837238250748], [45, 0.223804296234063], [24, 0.22354248955583034], [28, 0.2028647337245482], [1, 0.2008730051470726], [30, 0.19429973072830733], [11, 0.1904010252771333], [9, 0.1869994540208215], [22, 0.18647814121754064], [34, 0.1857815633341525], [39, 0.1796112502631851], [43, 0.15702937135518158], [6, 0.15214700008471815], [37, 0.1476582779542674], [46, 0.13901301991179618], [3, 0.13583501878960438], [21, 0.13556726710895864], [8, 0.13310361275314977], [5, 0.11315330213718917], [20, 0.11287489412020142], [42, 0.11207762615456289], [40, 0.08446300543813627], [4, 0.07751248291768069], [10, 0.07718730153063584], [26, 0.05461255488070687]]
# 0.5878484163397365
# 0.4895949816622442
# 0.4868924591747626
# 0.483931399140292
# 0.4453476949256825
# 0.4197834543587954
# 0.7159727474981017
# 0.6859885359753104
# 0.6218273362180861
# 0.6032011727624554
# 0.5458542818600346
# 0.5100311395860773
# 0.4877807668466736
# 0.48620587939701765
# 0.48232522147646656
# 0.4535974651545737
# 0.45334021543348185
# 0.45116572836132224
# 0.4318859868230383
# 0.42823162860802616
# 0.4240512826035208
# 0.41267182854687356
# 0.4007127553621756
# 0.36673210053743016
# 0.3526406641282529
# 0.347350393040867
# 0.3301347022161129
# 0.33002015686579156
# 0.3299100629211613
# 0.30552712526372344
# 0.29609504682707377
# 0.2949518755455396
# 0.27034692941322985
# 0.26382389855207294
# 0.24354351087694734
# 0.24091840782331087
# 0.2296787593757882
# 0.20064896698517737
# 0.19761038370225975
# 0.16164910977050093
# 0.15826973373664638
# 0.15457968121516039
# 0.14032879143673724
# 0.1302619454779098
# 0.10860921557948941
# 0.09572526661826956
# 0.09443985607000703
# 0.07836584698593671
# 0.04458187414003459
# 0.037571074185684686
# 0.022980771969343387
# -0.00836311075248903
# -0.009334844356475138
# MEND151
# |2025-10-29|11:18:15.272| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:15.388| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# |2025-10-29|11:18:15.476| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:15.595| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Building loaders
# Finished loading all files
# Finished building loaders
# Finished loading model
# 100%|███████████████████████████████████████████| 11/11 [00:06<00:00,  1.68it/s]
# |2025-10-29|11:18:22.345| [WARNING] /tmp/ipykernel_620191/3944429404.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds = model.img_linear(torch.tensor(each).float().unsqueeze(0).cuda())
# Finished loading model
# Mean Pearson correlation across All spots (genewise correlation):  0.8870960066607673
# Mean Spearman correlation across spots:  0.8469247074600176
# Mean Cosine Similarity across spots:  0.9786433507877501
# Mean Pearson correlation across pathways:  0.37712748428071036
# Mean Spearman correlation across pathways:  0.37771768806217315
# Mean Cosine Similarity across pathways:  0.9651160804046115
# (2566, 47)
# mean Pearson correlation highly expressed pathways:  0.6732793225877127
# mean Pearson correlation highly variable pathways:  0.7336290107950061
# Mean PCC of pathways having correlation value >=0.1 0.423373247073981
# Total number of Such Pathways 41
# [[14, 0.7961335642837043], [29, 0.7729535371015694], [15, 0.7549530788504784], [33, 0.6935328645538047], [27, 0.6505720091854731], [25, 0.631863272532256], [41, 0.6209341165698902], [23, 0.6192415547522887], [16, 0.6089089168418621], [19, 0.6002714730175003], [32, 0.5804712299962762], [18, 0.5767456962537825], [22, 0.5586916432738118], [44, 0.5454419442491153], [38, 0.49518853664562573], [17, 0.4892570698435234], [9, 0.4862879906425238], [31, 0.4831952870369993], [0, 0.46258320579831064], [35, 0.45320463781401216], [30, 0.39217456060541883], [45, 0.3886963151760209], [7, 0.36069856953228324], [39, 0.3429568160190389], [1, 0.33763746408712014], [2, 0.32756470897812306], [28, 0.3114143782104639], [24, 0.3096539266289648], [11, 0.2973378952767631], [20, 0.2795630779731246], [3, 0.2551472181939001], [36, 0.24556174141408152], [12, 0.23963566481381632], [43, 0.21872265776030145], [13, 0.216596703561697], [4, 0.21031587551039801], [34, 0.21022619734071035], [46, 0.17013885244693464], [6, 0.13775143636419743], [21, 0.1190850025265991], [37, 0.10699243837045296], [5, 0.09009093104901293], [42, 0.08970014069352363], [10, 0.08382045733513448], [8, 0.07400218186175292], [40, 0.02158897264665992], [26, 0.007485947574082414]]
# 0.7961335642837043
# 0.7729535371015694
# 0.7549530788504784
# 0.6935328645538047
# 0.6505720091854731
# 0.631863272532256
# 0.6209341165698902
# 0.6192415547522887
# 0.6089089168418621
# 0.6002714730175003
# 0.5804712299962762
# 0.5767456962537825
# 0.5586916432738118
# 0.5454419442491153
# 0.49518853664562573
# 0.4892570698435234
# 0.4862879906425238
# 0.4831952870369993
# 0.46258320579831064
# 0.45320463781401216
# 0.39217456060541883
# 0.3886963151760209
# 0.36069856953228324
# 0.3429568160190389
# 0.33763746408712014
# 0.32756470897812306
# 0.3114143782104639
# 0.3096539266289648
# 0.2973378952767631
# 0.2795630779731246
# 0.2551472181939001
# 0.24556174141408152
# 0.23963566481381632
# 0.21872265776030145
# 0.216596703561697
# 0.21031587551039801
# 0.21022619734071035
# 0.17013885244693464
# 0.13775143636419743
# 0.1190850025265991
# 0.10699243837045296
# 0.09009093104901293
# 0.08970014069352363
# 0.08382045733513448
# 0.07400218186175292
# 0.02158897264665992
# 0.007485947574082414
# MEND156
# |2025-10-29|11:18:23.203| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:23.313| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# |2025-10-29|11:18:23.401| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:23.516| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Building loaders
# Finished loading all files
# Finished building loaders
# Finished loading model
# 100%|███████████████████████████████████████████| 11/11 [00:06<00:00,  1.81it/s]
# |2025-10-29|11:18:29.785| [WARNING] /tmp/ipykernel_620191/3944429404.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds = model.img_linear(torch.tensor(each).float().unsqueeze(0).cuda())
# Finished loading model
# Mean Pearson correlation across All spots (genewise correlation):  0.71825672692797
# Mean Spearman correlation across spots:  0.6441030541243751
# Mean Cosine Similarity across spots:  0.9868080087204911
# Mean Pearson correlation across pathways:  0.01825833031630807
# Mean Spearman correlation across pathways:  0.03847423329334684
# Mean Cosine Similarity across pathways:  0.9753766350201389
# (2585, 47)
# mean Pearson correlation highly expressed pathways:  0.0032864868662275323
# mean Pearson correlation highly variable pathways:  0.017580013962080015
# Mean PCC of pathways having correlation value >=0.1 0.21525305537621883
# Total number of Such Pathways 12
# [[16, 0.5580932002892578], [1, 0.366388975500476], [39, 0.35246259532151397], [8, 0.19381027858804525], [21, 0.1896043782903426], [46, 0.16706678935740127], [37, 0.15153093548406923], [26, 0.15037223919604742], [30, 0.12621359683489974], [38, 0.12048283756030627], [15, 0.10640076078637503], [28, 0.10061007730589112], [7, 0.09408115284361371], [44, 0.09351442026843966], [25, 0.0817355862996223], [41, 0.07167331432913313], [19, 0.05790358017470715], [9, 0.040038286613667914], [35, 0.020987446362917977], [34, 0.017041625667204345], [20, 0.007015059754219562], [17, 0.004936625152472825], [5, -0.001158459486120409], [23, -0.004115490330003692], [0, -0.007572481903358973], [24, -0.029751538747958193], [43, -0.03310969780899443], [13, -0.03549268134139549], [12, -0.04145927121030832], [14, -0.04494749419858629], [36, -0.049379828890538775], [4, -0.05218316586207528], [6, -0.05339011320364187], [3, -0.05850503353842953], [45, -0.06283410667758124], [31, -0.06673196718639712], [40, -0.07722788195985542], [18, -0.07947004966807857], [33, -0.0899455958903423], [32, -0.0915473266246839], [27, -0.10568066828827578], [10, -0.16094461791053427], [29, -0.1669591888301695], [42, -0.19626201981870825], [22, -0.2218597884593927], [2, -0.23983217268728035], [11, -0.2434615965914346]]
# 0.5580932002892578
# 0.366388975500476
# 0.35246259532151397
# 0.19381027858804525
# 0.1896043782903426
# 0.16706678935740127
# 0.15153093548406923
# 0.15037223919604742
# 0.12621359683489974
# 0.12048283756030627
# 0.10640076078637503
# 0.10061007730589112
# 0.09408115284361371
# 0.09351442026843966
# 0.0817355862996223
# 0.07167331432913313
# 0.05790358017470715
# 0.040038286613667914
# 0.020987446362917977
# 0.017041625667204345
# 0.007015059754219562
# 0.004936625152472825
# -0.001158459486120409
# -0.004115490330003692
# -0.007572481903358973
# -0.029751538747958193
# -0.03310969780899443
# -0.03549268134139549
# -0.04145927121030832
# -0.04494749419858629
# -0.049379828890538775
# -0.05218316586207528
# -0.05339011320364187
# -0.05850503353842953
# -0.06283410667758124
# -0.06673196718639712
# -0.07722788195985542
# -0.07947004966807857
# -0.0899455958903423
# -0.0915473266246839
# -0.10568066828827578
# -0.16094461791053427
# -0.1669591888301695
# -0.19626201981870825
# -0.2218597884593927
# -0.23983217268728035
# -0.2434615965914346
# MEND158
# |2025-10-29|11:18:30.656| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:30.788| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# |2025-10-29|11:18:30.875| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:31.016| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Building loaders
# Finished loading all files
# Finished building loaders
# Finished loading model
# 100%|█████████████████████████████████████████████| 9/9 [00:05<00:00,  1.66it/s]
# |2025-10-29|11:18:36.604| [WARNING] /tmp/ipykernel_620191/3944429404.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds = model.img_linear(torch.tensor(each).float().unsqueeze(0).cuda())
# Finished loading model
# Mean Pearson correlation across All spots (genewise correlation):  0.4895090500145339
# Mean Spearman correlation across spots:  0.44196890618920437
# Mean Cosine Similarity across spots:  0.9725603086290929
# Mean Pearson correlation across pathways:  0.36794676536540655
# Mean Spearman correlation across pathways:  0.3239889712506235
# Mean Cosine Similarity across pathways:  0.9649441167934267
# (2283, 47)
# mean Pearson correlation highly expressed pathways:  0.4532316074913444
# mean Pearson correlation highly variable pathways:  0.40038274248467837
# Mean PCC of pathways having correlation value >=0.1 0.36794676536540655
# Total number of Such Pathways 47
# [[26, 0.5473867229691574], [40, 0.5314439202676929], [42, 0.523758269006234], [6, 0.5132908849928963], [2, 0.5110655626052261], [7, 0.5083222635838396], [18, 0.49087747920575936], [19, 0.48656098011647936], [11, 0.4809652918103393], [12, 0.47823279857851203], [46, 0.469924901989546], [45, 0.4668646194293625], [13, 0.4651671598677395], [24, 0.46020994210375427], [17, 0.4334024534733814], [37, 0.4303952538533281], [43, 0.4283832358878276], [31, 0.42824446386956333], [34, 0.42673510141841314], [3, 0.41600037917285687], [32, 0.415793974188691], [36, 0.38075241332494847], [1, 0.37938425067445264], [8, 0.36995250477231956], [22, 0.36722213275713045], [5, 0.3596571700329187], [0, 0.35847101923802704], [20, 0.3547728036531913], [25, 0.34751774089688037], [10, 0.3371885344137546], [41, 0.3298635964798152], [38, 0.32578152799466437], [14, 0.31005338222983686], [28, 0.3075362419759876], [44, 0.3044955175869986], [27, 0.30089306845109276], [23, 0.2906010448128121], [30, 0.2888537038565958], [21, 0.2855959267583234], [9, 0.23522800075921343], [16, 0.1970172997717308], [39, 0.18965708188782604], [15, 0.18727953963930427], [29, 0.15392283671786053], [33, 0.14957925854387755], [4, 0.13928293349821963], [35, 0.1299127830557271]]
# 0.5473867229691574
# 0.5314439202676929
# 0.523758269006234
# 0.5132908849928963
# 0.5110655626052261
# 0.5083222635838396
# 0.49087747920575936
# 0.48656098011647936
# 0.4809652918103393
# 0.47823279857851203
# 0.469924901989546
# 0.4668646194293625
# 0.4651671598677395
# 0.46020994210375427
# 0.4334024534733814
# 0.4303952538533281
# 0.4283832358878276
# 0.42824446386956333
# 0.42673510141841314
# 0.41600037917285687
# 0.415793974188691
# 0.38075241332494847
# 0.37938425067445264
# 0.36995250477231956
# 0.36722213275713045
# 0.3596571700329187
# 0.35847101923802704
# 0.3547728036531913
# 0.34751774089688037
# 0.3371885344137546
# 0.3298635964798152
# 0.32578152799466437
# 0.31005338222983686
# 0.3075362419759876
# 0.3044955175869986
# 0.30089306845109276
# 0.2906010448128121
# 0.2888537038565958
# 0.2855959267583234
# 0.23522800075921343
# 0.1970172997717308
# 0.18965708188782604
# 0.18727953963930427
# 0.15392283671786053
# 0.14957925854387755
# 0.13928293349821963
# 0.1299127830557271
# MEND160
# |2025-10-29|11:18:37.375| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:37.501| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# |2025-10-29|11:18:37.597| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:18:37.707| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Building loaders
# Finished loading all files
# Finished building loaders
# Finished loading model
# 100%|███████████████████████████████████████████| 13/13 [00:07<00:00,  1.63it/s]
# |2025-10-29|11:18:45.896| [WARNING] /tmp/ipykernel_620191/3944429404.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds = model.img_linear(torch.tensor(each).float().unsqueeze(0).cuda())
# Finished loading model
# Mean Pearson correlation across All spots (genewise correlation):  0.4769329299083334
# Mean Spearman correlation across spots:  0.42999262645304037
# Mean Cosine Similarity across spots:  0.9675341665974136
# Mean Pearson correlation across pathways:  0.06247551488833085
# Mean Spearman correlation across pathways:  0.05531654062102923
# Mean Cosine Similarity across pathways:  0.9407194891727496
# (3234, 47)
# mean Pearson correlation highly expressed pathways:  0.10666341615212782
# mean Pearson correlation highly variable pathways:  0.09524329544568992
# Mean PCC of pathways having correlation value >=0.1 0.169247060955171
# Total number of Such Pathways 17
# [[26, 0.31721064130510485], [46, 0.25676902274815055], [40, 0.23165624388597064], [6, 0.21541015386760412], [16, 0.18745835804436767], [43, 0.1736089839191121], [28, 0.1726305549581921], [30, 0.1622531258847775], [7, 0.15866078374698395], [24, 0.14116485236813447], [42, 0.1351650618297088], [8, 0.13468769373803233], [5, 0.13243115538965608], [17, 0.12491698123242616], [19, 0.1234698549549693], [37, 0.1059975041360012], [12, 0.103709064228715], [18, 0.08857803710768028], [21, 0.08560699461678489], [10, 0.08478297033801221], [32, 0.07533132360214259], [34, 0.05666074543943013], [20, 0.04705212158095146], [0, 0.04564307100217644], [2, 0.04336423682509694], [45, 0.041773433030968456], [13, 0.037616264556948845], [39, 0.034995432468474925], [31, 0.033956622664282704], [38, 0.033712017702500555], [44, 0.025752331791286224], [11, 0.01733529593810387], [3, 0.014836895518229464], [1, 0.009546411796819221], [41, 0.006679562681390699], [22, 0.004960560140112669], [23, -0.002825392267511108], [27, -0.0070637076198032354], [4, -0.01606940618948381], [25, -0.022206309308617667], [14, -0.037354236853103094], [36, -0.05328062402911824], [35, -0.09100941073960661], [33, -0.09593908061156489], [15, -0.10773917538732497], [9, -0.13054949979247965], [29, -0.1649983224891363]]
# 0.31721064130510485
# 0.25676902274815055
# 0.23165624388597064
# 0.21541015386760412
# 0.18745835804436767
# 0.1736089839191121
# 0.1726305549581921
# 0.1622531258847775
# 0.15866078374698395
# 0.14116485236813447
# 0.1351650618297088
# 0.13468769373803233
# 0.13243115538965608
# 0.12491698123242616
# 0.1234698549549693
# 0.1059975041360012
# 0.103709064228715
# 0.08857803710768028
# 0.08560699461678489
# 0.08478297033801221
# 0.07533132360214259
# 0.05666074543943013
# 0.04705212158095146
# 0.04564307100217644
# 0.04336423682509694
# 0.041773433030968456
# 0.037616264556948845
# 0.034995432468474925
# 0.033956622664282704
# 0.033712017702500555
# 0.025752331791286224
# 0.01733529593810387
# 0.014836895518229464
# 0.009546411796819221
# 0.006679562681390699
# 0.004960560140112669
# -0.002825392267511108
# -0.0070637076198032354
# -0.01606940618948381
# -0.022206309308617667
# -0.037354236853103094
# -0.05328062402911824
# -0.09100941073960661
# -0.09593908061156489
# -0.10773917538732497
# -0.13054949979247965
# -0.1649983224891363

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib as mpl
import cv2
import json

# %%
def get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,g_names):
    spatial = tissue_position_list_data.loc[tissue_position_list_data[1] == 1, [4, 5]].values
    reversed_array = np.array([[sub_array[1], sub_array[0]] for sub_array in spatial])
    scalefactor_data = scalefactor_file_path
    adata = sc.AnnData(X=data_array)
    if 'spatial' not in adata.uns:
        adata.uns['spatial'] = {}
    if 'C1' not in adata.uns['spatial']:
        adata.uns['spatial']['ST'] = {}

    if 'images' not in adata.uns['spatial']:
        adata.uns['spatial']['ST']['images'] = {}

    if 'scalefactors' not in adata.uns:
        adata.uns['spatial']['ST']['scalefactors'] = {}
    adata.var_names = g_names
    adata.uns['spatial']['ST']['images']['downscaled_fullres'] = hi_res_image_data
    adata.obsm['spatial']= np.array(reversed_array)
    adata.uns['spatial']['ST']['scalefactors']=scalefactor_data
    new_df=pd.DataFrame()
    new_df.index = tissue_position_list_data[0].values
    new_df['in_tissue']=tissue_position_list_data[1].values
    new_df['array_row']=tissue_position_list_data[2].values
    new_df['array_col']=tissue_position_list_data[3].values
    adata.obs=new_df
    return adata

# %%
adata= adata = sc.read_h5ad(root_path+"st/MEND158.h5ad")

# %%
root_path
# Out:
# '/home/e90244aa/Bleep/prostate cancer/'

# %%
tissue_position_list_data = pd.read_csv(root_path+"MEND158_tissue_position_list.csv",sep=',',header=None)
barcode_data = pd.read_csv("/home/e90244aa/Bleep/DeepPathway/prostate cancer dataset/filtered_barcodes/"+"MEND158_sample_filtered_barcodes_1.tsv",sep="\t",header=None)
modified_tissue_position_list = tissue_position_list_data[tissue_position_list_data[0].isin(barcode_data[0])]
res=[]
for each in barcode_data[0]:
    a = list(tissue_position_list_data[tissue_position_list_data[0]==each].values[0])
    res.append(a)
res=pd.DataFrame(res)

# %%
tissue_position_list_data = res
scalefactor_file_path=adata.uns['spatial']['ST']['scalefactors']
hi_res_image_data = adata.uns['spatial']['ST']['images']['downscaled_fullres']

# %%
with open(root_path+"bleep_pathway_expression/"+"pathway_dic_prostate_msig47.json", 'r') as file:
    g_names = json.load(file)
g_names = list(g_names.keys())

# %%
len(g_names)
# Out:
# 47

# %%
plt.imshow(hi_res_image_data)
plt.show()

# %%
import matplotlib as mpl

# %%
sdata = read_zarr(root_path+"SpatialData/MEND158_spatial_data.zarr")
true=sdata['adata_pathways'].X

# %%
data_array =true
marker_gene_name=g_names[26]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,g_names)
fig=sc.pl.spatial(adata,
              color=marker_gene_name,
              size=1.5,
              show=False,
              return_fig=True,
              color_map=mpl.cm.Reds,
              img_key=None)
cbar = fig.axes[-1]  # usually the last Axes is the colorbar
cbar.tick_params(labelsize=16)
plt.title("")
plt.xlabel("")
plt.ylabel("")
plt.show()
# Out:
# |2025-10-29|12:07:11.933| [WARNING] /tmp/ipykernel_620191/3901957732.py:4: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   fig=sc.pl.spatial(adata,

# %%
data_array =true
marker_gene_name=g_names[26]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,g_names)
sc.pl.spatial(adata,
              color=None,
              img_key="downscaled_fullres")
# Out:
# |2025-10-29|12:06:46.007| [WARNING] /tmp/ipykernel_620191/546482110.py:4: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata,

# %%
a= ["MEND158"]
for sample_name in a:
    print(sample_name)
    model_path_1 = root_path+"itr_01_Bleep+optimus_prostate_pathways_mixed_patients.pt"
    model_path_2 = root_path+"itr_01_cnn+mlp+optimus_prostate_pathways_mixed_patients.pt"
    dev_name = "cuda:0"
    device = torch.device(dev_name)
    model1= CLIPModel().to(device)
    model2 = MyModel(dev_name,root_path).to(device)
    img_embeddings_all= get_image_embeddings_1(model_path_1, model1,sample_name)
    pred = get_image_embeddings_2(model_path_2,model2,img_embeddings_all).cpu().numpy()
    sdata = read_zarr(root_path+"SpatialData/"+sample_name+"_spatial_data.zarr")
    true=sdata['adata_pathways'].X
    get_statistics(true,pred)
    get_PCC_dist(true,pred)
# Out:
# MEND158
# |2025-10-29|11:51:53.672| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:51:53.819| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# |2025-10-29|11:51:53.915| [INFO] Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# |2025-10-29|11:51:54.023| [INFO] [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Building loaders
# Finished loading all files
# Finished building loaders
# Finished loading model
# 100%|█████████████████████████████████████████████| 9/9 [00:05<00:00,  1.67it/s]
# |2025-10-29|11:51:59.594| [WARNING] /tmp/ipykernel_620191/3944429404.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds = model.img_linear(torch.tensor(each).float().unsqueeze(0).cuda())
# Finished loading model
# Mean Pearson correlation across All spots (genewise correlation):  0.4895090500145339
# Mean Spearman correlation across spots:  0.44196890618920437
# Mean Cosine Similarity across spots:  0.9725603086290929
# Mean Pearson correlation across pathways:  0.36794676536540655
# Mean Spearman correlation across pathways:  0.3239889712506235
# Mean Cosine Similarity across pathways:  0.9649441167934267
# (2283, 47)
# mean Pearson correlation highly expressed pathways:  0.4532316074913444
# mean Pearson correlation highly variable pathways:  0.40038274248467837
# Mean PCC of pathways having correlation value >=0.1 0.36794676536540655
# Total number of Such Pathways 47
# [[26, 0.5473867229691574], [40, 0.5314439202676929], [42, 0.523758269006234], [6, 0.5132908849928963], [2, 0.5110655626052261], [7, 0.5083222635838396], [18, 0.49087747920575936], [19, 0.48656098011647936], [11, 0.4809652918103393], [12, 0.47823279857851203], [46, 0.469924901989546], [45, 0.4668646194293625], [13, 0.4651671598677395], [24, 0.46020994210375427], [17, 0.4334024534733814], [37, 0.4303952538533281], [43, 0.4283832358878276], [31, 0.42824446386956333], [34, 0.42673510141841314], [3, 0.41600037917285687], [32, 0.415793974188691], [36, 0.38075241332494847], [1, 0.37938425067445264], [8, 0.36995250477231956], [22, 0.36722213275713045], [5, 0.3596571700329187], [0, 0.35847101923802704], [20, 0.3547728036531913], [25, 0.34751774089688037], [10, 0.3371885344137546], [41, 0.3298635964798152], [38, 0.32578152799466437], [14, 0.31005338222983686], [28, 0.3075362419759876], [44, 0.3044955175869986], [27, 0.30089306845109276], [23, 0.2906010448128121], [30, 0.2888537038565958], [21, 0.2855959267583234], [9, 0.23522800075921343], [16, 0.1970172997717308], [39, 0.18965708188782604], [15, 0.18727953963930427], [29, 0.15392283671786053], [33, 0.14957925854387755], [4, 0.13928293349821963], [35, 0.1299127830557271]]
# 0.5473867229691574
# 0.5314439202676929
# 0.523758269006234
# 0.5132908849928963
# 0.5110655626052261
# 0.5083222635838396
# 0.49087747920575936
# 0.48656098011647936
# 0.4809652918103393
# 0.47823279857851203
# 0.469924901989546
# 0.4668646194293625
# 0.4651671598677395
# 0.46020994210375427
# 0.4334024534733814
# 0.4303952538533281
# 0.4283832358878276
# 0.42824446386956333
# 0.42673510141841314
# 0.41600037917285687
# 0.415793974188691
# 0.38075241332494847
# 0.37938425067445264
# 0.36995250477231956
# 0.36722213275713045
# 0.3596571700329187
# 0.35847101923802704
# 0.3547728036531913
# 0.34751774089688037
# 0.3371885344137546
# 0.3298635964798152
# 0.32578152799466437
# 0.31005338222983686
# 0.3075362419759876
# 0.3044955175869986
# 0.30089306845109276
# 0.2906010448128121
# 0.2888537038565958
# 0.2855959267583234
# 0.23522800075921343
# 0.1970172997717308
# 0.18965708188782604
# 0.18727953963930427
# 0.15392283671786053
# 0.14957925854387755
# 0.13928293349821963
# 0.1299127830557271

# %%
data_array =pred
marker_gene_name=g_names[26]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,g_names)
fig=sc.pl.spatial(adata,
              color=marker_gene_name,
              size=1.5,
              show=False,
              return_fig=True,
              color_map=mpl.cm.Reds,
              img_key=None)
cbar = fig.axes[-1]  # usually the last Axes is the colorbar
cbar.tick_params(labelsize=16)
plt.title("")
plt.xlabel("")
plt.ylabel("")
plt.show()
# Out:
# |2025-10-29|11:54:30.963| [WARNING] /tmp/ipykernel_620191/1930765558.py:4: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   fig=sc.pl.spatial(adata,

# %%
pred2 =np.load(root_path+second_path+"INT25_46_pathways_msig_prostate_Ucell_from_predicted_gene_expression.npy")

# %%
data_array =pred2
marker_gene_name=[g_names[i] for i in list_indices]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,g_names)
sc.pl.spatial(adata,
              color=marker_gene_name,
              size=1.5,
              # save="01gt_150_pathway_H&E.png",
              color_map=mpl.cm.Reds,
#               vmin=vmin,
#               vmax=vmax,
              img_key=None)

# %%
list_indices

# %%
#true is the original ground truth, i.e., pathway expression from original gene expression data using UCell.
pred=pred2
res=[]
res2=[]
res3=[]
for i in range(0,46):
    a=(true[:,i]-np.mean(true[:,i]))/np.std(true[:,i])
    if i==1:
        print(true[:,i].shape)
    b = (pred[:,i]-np.mean(pred[:,i]))/np.std(pred[:,i])
    x = np.corrcoef(true[:,i], pred[:,i])[0,1]
    res2.append([i,x])
    res3.append(x)
    res.append(np.corrcoef(a, b)[0,1])

# %%
res_sorted=np.array(sorted(res,reverse=True))
res3_sorted = np.array(sorted(res3,reverse=True))
res3_sorted = res3_sorted[~np.isnan(res3_sorted)]
th=0.10
print("Mean PCC of pathways having correlation value >="+str(th)+"with Normalization",np.mean(res_sorted[res_sorted>=th]))

print("Mean PCC of pathways having correlation value >="+str(th)+"without Normalization",np.mean(res3_sorted[res3_sorted>=th]))

print("Total number of Such Pathways",len(res3_sorted[res3_sorted>=th]))

# %%
import math
def contains_nan(sublist):
    return any(isinstance(item, float) and math.isnan(item) for item in sublist)

# Filter out sublists that contain NaN
cleaned_data = [sublist for sublist in res2 if not contains_nan(sublist)]
sorted_data = sorted(cleaned_data, key=lambda x: x[1], reverse=True)

# %%
sorted_data

# %%
from numpy.linalg import norm
from scipy import stats
corr_cells = np.zeros(pred.shape[0])
sp_corr_cells = np.zeros(pred.shape[0])
cosine_cells = np.zeros(pred.shape[0])
for i in range(pred.shape[0]):
    corr_cells[i] = np.corrcoef(pred[i,:], true[i,:])[0,1]
    sp_corr_cells[i]=stats.spearmanr(pred[i,:], true[i,:])[0]
    cosine_cells[i] = np.dot(pred[i,:], true[i,:])/(norm(pred[i,:])*norm(true[i,:]))

corr_cells = corr_cells[~np.isnan(corr_cells)]
sp_corr_cells = sp_corr_cells[~np.isnan(sp_corr_cells)]
cosine_cells = cosine_cells[~np.isnan(cosine_cells)]


print("Mean Pearson correlation across All spots (genewise correlation): ", np.mean(corr_cells))
print("Mean Spearman correlation across spots: ", np.mean(sp_corr_cells))
print("Mean Cosine Similarity across spots: ", np.mean(cosine_cells))


corr_pathways = np.zeros(pred.shape[1])
sp_corr_paths=np.zeros(pred.shape[1])
cosine_pathways = np.zeros(pred.shape[1])
for i in range(pred.shape[1]):
    corr_pathways[i] = np.corrcoef(pred[:,i], true[:,i],)[0,1]
    sp_corr_paths[i]=stats.spearmanr(pred[:,i], true[:,i])[0]
    cosine_pathways[i] = np.dot(pred[:,i], true[:,i])/(norm(pred[:,i])*norm(true[:,i]))

corr_pathways = corr_pathways[~np.isnan(corr_pathways)]
sp_corr_paths = sp_corr_paths[~np.isnan(sp_corr_paths)]
cosine_pathways = cosine_pathways[~np.isnan(cosine_pathways)]


print("Mean Pearson correlation across pathways: ", np.mean(corr_pathways))

print("Mean Spearman correlation across pathways: ", np.mean(sp_corr_paths))
print("Mean Cosine Similarity across pathways: ", np.mean(cosine_pathways))
true_filetered=[]
for k in range(0,corr_pathways.shape[0]):
    if corr_pathways[k] ==np.nan:
        continue
    else:
        true_filetered.append(true[:, k])
true_filetered = np.array(true_filetered).T
print(true_filetered.shape)
ind = np.argsort(np.sum(true_filetered, axis=0))[-5:]
# print("highly expressed indices",ind)
print("mean Pearson correlation highly expressed pathways: ", np.mean(corr_pathways[ind]))
# print("mean Spearman correlation highly expressed pathways: ", np.mean(sp_corr_paths[ind]))
ind = np.argsort(np.var(true_filetered, axis=0))[-5:]
# print("highly variable indices",ind)
print("mean Pearson correlation highly variable pathways: ", np.mean(corr_pathways[ind]))
# print("mean Spearman correlation highly variable pathways: ", np.mean(sp_corr_paths[ind]))

# %%
data_array =true
marker_gene_name=g_names[list_indices[2]]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T259_"+marker_gene_name+"_GT_gbm_genes.pdf", format="pdf", bbox_inches="tight")
# fig.show()
data_array =pred
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T259_"+marker_gene_name+"_pred_gbm_genes.pdf", format="pdf", bbox_inches="tight")

# %%
data_array =true
marker_gene_name=g_names[list_indices[1]]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T296_"+marker_gene_name+"_GT_kegg_gbm_genes.pdf", format="pdf", bbox_inches="tight")
# fig.show()
data_array =pred
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T296_"+marker_gene_name+"_pred_kegg_gbm_genes.pdf", format="pdf", bbox_inches="tight")

# %%
data_array =true
marker_gene_name=g_names[list_indices[2]]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T296_"+marker_gene_name+"_GT_kegg_gbm_genes.pdf", format="pdf", bbox_inches="tight")
# fig.show()
data_array =pred
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T296_"+marker_gene_name+"_pred_kegg_gbm_genes.pdf", format="pdf", bbox_inches="tight")

# %%
data_array =true
marker_gene_name=g_names[list_indices[3]]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T296_"+marker_gene_name+"_GT_kegg_gbm_genes.pdf", format="pdf", bbox_inches="tight")
# fig.show()
data_array =pred
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T296_"+marker_gene_name+"_pred_kegg_gbm_genes.pdf", format="pdf", bbox_inches="tight")

# %%
data_array =true
marker_gene_name=g_names[list_indices[4]]
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T259_"+marker_gene_name+"_GT_kegg_gbm_genes.pdf", format="pdf", bbox_inches="tight")
# fig.show()
data_array =pred
adata =get_adata_object(tissue_position_list_data,scalefactor_file_path,data_array,hi_res_image_data,low_res_image_data,g_names)
fig=sc.pl.spatial(adata,color=marker_gene_name,size=1.5,color_map=mpl.cm.Reds,return_fig=True,img_key=None,show=False)
ax=fig.axes[0]
ax.set_title(marker_gene_name, fontsize=14)
ax.set_xlabel("spatial 1", fontsize=14)
ax.set_ylabel("spatial 2", fontsize=14)
fig.savefig(root_path+second_path+"/figures/"+"T259_"+marker_gene_name+"_pred_kegg_gbm_genes.pdf", format="pdf", bbox_inches="tight")

# %%
pd.read_csv(root_path+second_path+"INT27_50_pathways_msig_prostate_Ucell_from_predicted_gene_expression_02.csv").iloc[:,1:].shape
