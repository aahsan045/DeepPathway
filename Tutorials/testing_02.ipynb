# %%
import omicverse as ov
# Out:
#    ____            _     _    __
#   / __ \____ ___  (_)___| |  / /__  _____________
#  / / / / __ `__ \/ / ___/ | / / _ \/ ___/ ___/ _ \
# / /_/ / / / / / / / /__ | |/ /  __/ /  (__  )  __/
# \____/_/ /_/ /_/_/\___/ |___/\___/_/  /____/\___/
#
# Version: 1.6.6, Tutorials: https://omicverse.readthedocs.io/

# %%
# %run data_processing
# Out:
# |2025-04-25|18:28:27.931| [WARNING] It looks like you are using Pixman version 0.38 (via conda). This version is known to cause issues with OpenSlide. Please consider upgrading to Pixman version 0.39 or later. You may be able do this with the command: conda install -c conda-forge pixman">=0.39"
# Starting gene processing.....
#
# Total Number of unique genes in all pathways:  4383
# 10000 10000
# 12135 10000
# 14524 10000
# 15615 10000
# No. of unique genes after filtering 16727
# No. of Common genes between unique pathway genes and unique filtered genes from all samples 3900
# (3551, 3900)
# (3864, 3900)
# (4152, 3900)
# (3990, 3900)
# (3916, 3900)
# Saving the Filtered Barcodes after spot filtering
# Starting Image Processing......
# SAMPLE Name:  INT25
# |2025-04-25|18:28:41.367| [WARNING] Raw data is None.
# |2025-04-25|18:28:41.368| [WARNING] Unknown scale (no objective_power or mpp)
# Original Image Shape:  (13998, 14315, 3)
# Pixel Resolution 0.616
# ...

# %%
# %run train.py  # new_model_for_deployment

# %%
# %run test.py
# Out:
# Building loaders
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished loading all files
# Finished building inference loaders
# Finished loading model
# 100%|███████████████████████████████████████████| 76/76 [00:49<00:00,  1.54it/s]
# image query shape:  (3989, 256)
# spot_key shape:  (15256, 256)
# expression_key shape:  (15256, 50)
# finding matches, using average of top 10 expressions
# torch.Size([3989, 15256])
# matched spot embeddings pred shape:  (3989, 256)
# matched spot expression pred shape:  (3989, 50)
# Mean Pearson correlation across All spots (genewise correlation):  0.9154910118176565
# Mean Spearman correlation across spots:  0.8950333589223759
# Mean Cosine Similarity across spots:  0.9861662673713372
# Mean Pearson correlation across pathways:  0.27326945450782913
# Mean Spearman correlation across pathways:  0.32116142706602047
# Mean Cosine Similarity across pathways:  0.9687527845863987
# ...

# %%
# !pwd
# Out:
# /home/e90244aa/Bleep/Hist2Pathway
